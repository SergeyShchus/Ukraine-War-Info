# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
df = pd.read_excel(r"D:\2022\satellite\Crimea\Objects.xlsx")  
df.head()
# Out:
#     4                                   место дислокации  \
# 0   5                                                NaN
# 1   7  г. Севастополь,                               ...
# 2   8                                                NaN
# 3   9                    г. Севастополь, Мекензиевы горы
# 4  10  г. Севастополь,                               ...
#
#   Наименование вч, организаций и предприятий расквартированых в военном городке  \
# 0                                                NaN
# 1             Филиал ТБВ (мт) войсковой части 63876
# 2                                 ФГУП 102 ПЭС МО РФ
# 3                      БГ (п) войсковой части 63876
# 4                              войсковая часть 80159
#
#   Номера зданий и сооружений закрепленых за вч, организациями и предприятиями и отведеных им земельным участкам  \
# 0                                                NaN
# 1  1,2,3,4,6,7,8,9,10,11,12,16,18,19,20,21,22,25,...
# 2                                                 52
# 3                                                NaN
# 4                                                  —
#
#    № земельного участка, площадь Unnamed: 5  \
# 0                            NaN        NaN
# 1                            NaN     73 970
# 2                            NaN        NaN
# 3        91:04:004        003:31     18 626
# 4  91:04:006               002:4     10 873
#
#                                          Unnamed: 6  \
# 0                                               NaN
# 1             Начальник филиала ТБВ (мт) в/ч 63876
# 2                       Директор ФГУП 102 ПЭС МО РФ
# 3  Начальник БГ (п)                       в/ч 63876
# 4                                Командир в/ч 80159
#
#                                           Unnamed: 7
# 0                                                NaN
# 1              Начальник филиала ТБВ (мт) в/ч 63876
# 2                                                NaN
# 3      Начальник                    БГ (п) в/ч 63876
# 4  Командир                                в/ч 80159

# %%
# удалить пробелы
df = df.replace(r'\s+','',regex=True)

# %%
df.head()
# Out:
#    NaN               место дислокации  \
# 0    5                            NaN
# 1    7  г.Севастополь,ул.Мореходная,1
# 2    8                            NaN
# 3    9   г.Севастополь,Мекензиевыгоры
# 4   10    г.Севастополь,пос.Любимовка
#
#   Наименование вч, организаций и предприятий расквартированых в военном городке  \
# 0                                                NaN
# 1                   ФилиалТБВ(мт)войсковойчасти63876
# 2                                     ФГУП102ПЭСМОРФ
# 3                           БГ(п)войсковойчасти63876
# 4                                войсковаячасть80159
#
#   Номера зданий и сооружений закрепленых за вч, организациями и предприятиями и отведеных им земельным участкам  \
# 0                                                NaN
# 1  1,2,3,4,6,7,8,9,10,11,12,16,18,19,20,21,22,25,...
# 2                                                 52
# 3                                                NaN
# 4                                                  —
#
#   № земельного участка, площадь Unnamed: 5                       Unnamed: 6  \
# 0                           NaN        NaN                              NaN
# 1                           NaN      73970  НачальникфилиалаТБВ(мт)в/ч63876
# 2                           NaN        NaN           ДиректорФГУП102ПЭСМОРФ
# 3               91:04:004003:31      18626           НачальникБГ(п)в/ч63876
# 4                91:04:006002:4      10873                 Командирв/ч80159
#
#                         Unnamed: 7
# 0                              NaN
# 1  НачальникфилиалаТБВ(мт)в/ч63876
# 2                              NaN
# 3           НачальникБГ(п)в/ч63876
# 4                 Командирв/ч80159

# %%
df = df.replace(r',',', ',regex=True)
df.head()
# Out:
#    NaN                 место дислокации  \
# 0    5                              NaN
# 1    7  г.Севастополь, ул.Мореходная, 1
# 2    8                              NaN
# 3    9    г.Севастополь, Мекензиевыгоры
# 4   10     г.Севастополь, пос.Любимовка
#
#   Наименование вч,  организаций и предприятий расквартированых в военном городке  \
# 0                                                NaN
# 1                   ФилиалТБВ(мт)войсковойчасти63876
# 2                                     ФГУП102ПЭСМОРФ
# 3                           БГ(п)войсковойчасти63876
# 4                                войсковаячасть80159
#
#   Номера зданий и сооружений закрепленых за вч,  организациями и предприятиями и отведеных им земельным участкам  \
# 0                                                NaN
# 1  1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12, 16, 18, 19...
# 2                                                 52
# 3                                                NaN
# 4                                                  —
#
#   № земельного участка,  площадь Unnamed: 5                       Unnamed: 6  \
# 0                            NaN        NaN                              NaN
# 1                            NaN      73970  НачальникфилиалаТБВ(мт)в/ч63876
# 2                            NaN        NaN           ДиректорФГУП102ПЭСМОРФ
# 3                91:04:004003:31      18626           НачальникБГ(п)в/ч63876
# 4                 91:04:006002:4      10873                 Командирв/ч80159
#
#                         Unnamed: 7
# 0                              NaN
# 1  НачальникфилиалаТБВ(мт)в/ч63876
# 2                              NaN
# 3           НачальникБГ(п)в/ч63876
# 4                 Командирв/ч80159

# %%
from geopandas.tools import geocode

# %%
from geopy.geocoders import Nominatim

# %%
geo = geocode(df['место дислокации'], provider='nominatim')
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-23-60d2d8bd6eb8> in <module>
# ----> 1 geo = geocode(df['место дислокации'], provider='nominatim')
#
# D:\gis-library\script\Conda\envs\arcgis\lib\site-packages\geopandas\tools\geocoding.py in geocode(strings, provider, **kwargs)
#      69         throttle_time = _get_throttle_time(provider)
#      70
# ---> 71     return _query(strings, True, provider, throttle_time, **kwargs)
#      72
#      73
#
# D:\gis-library\script\Conda\envs\arcgis\lib\site-packages\geopandas\tools\geocoding.py in _query(data, forward, provider, throttle_time, **kwargs)
#     138         provider = get_geocoder_for_service(provider)
#     139
# --> 140     coder = provider(**kwargs)
#     141     results = {}
#     142     for i, s in data.items():
#
# D:\gis-library\script\Conda\envs\arcgis\lib\site-packages\geopy\geocoders\nominatim.py in __init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     103         if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104                 and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105             raise ConfigurationError(
#     106                 'Using Nominatim with default or sample `user_agent` "%s" is '
#     107                 'strongly discouraged, as it violates Nominatim\'s ToS '
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.2.0" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.
